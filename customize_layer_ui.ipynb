# %%
from component import tile
from component import io
# Out:
# Styles()
# ResizeTrigger()

# %%
rp_layers_io = io.CustomizeLayerIo() 
rp_default_layers_io = io.CustomizeLayerIo()

# %%
# debug
from sepal_ui import aoi

rp_aoi_io = aoi.Aoi_io(default_admin0=253)
rp_aoi = aoi.TileAoi(rp_aoi_io)
rp_questionaire_io = io.default_questionnaire_io
rp_aoi
# Out:
# TileAoi(align_center=True, children=[Card(children=[Html(children=['AOI selection'], tag='h2'), Flex(children=…

# %%
rp_layers = tile.CustomizeLayerTile(rp_aoi, rp_layers_io, rp_questionaire_io)

# %%
rp_layers
# Out:
# CustomizeLayerTile(align_center=True, children=[Card(children=[Html(children=['Customize layers input'], tag='…

# %%
def update(change):
    
    if change['new'] == False:
        
        data = rp_layers.table.items 
        rp_layers.table.items = a
    
    return 

rp_layers.table.dialog_edit.observe(update, 'value')

# %%
rp_layers.table.items
# Out:
# [{'theme': 'benefits',
#   'subtheme': 'Wood production',
#   'name': 'Fuelwood consumption',
#   'weight': 6,
#   'layer': 'users/bornToBeAlive/random300'},
#  {'theme': 'benefits',
#   'subtheme': 'Wood production',
#   'name': 'Net imports of forest products',
#   'weight': 0,
#   'layer': 'projects/john-ee-282116/assets/fao-restoration/features/national_NetImportsPC'},
#  {'theme': 'benefits',
#   'subtheme': 'Wood production',
#   'name': 'Woody biomass plantation growth rates',
#   'weight': 0,
#   'layer': 'projects/john-ee-282116/assets/fao-restoration/features/yields-4326'},
#  {'theme': 'constraint',
#   'subtheme': 'Wood production',
#   'name': 'Accessibility to major cities',
#   'weight': 0,
#   'layer': 'Oxford/MAP/accessibility_to_cities_2015_v1_0'},
#  {'theme': 'benefits',
#   'subtheme': 'Wood production',
#   'name': 'Forest employment per ha of forest',
#   'weight': 0,
#   'layer': 'projects/john-ee-282116/assets/fao-restoration/features/emp_ha'},
# ...

# %%
a = [{'theme': 'benefits',
  'subtheme': 'Wood production',
  'name': 'Fuelwood consumption',
  'weight': 6,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'benefits',
  'subtheme': 'Wood production',
  'name': 'Net imports of forest products',
  'weight': 2,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/national_NetImportsPC'},
 {'theme': 'benefits',
  'subtheme': 'Wood production',
  'name': 'Woody biomass plantation growth rates',
  'weight': 3,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/yields-4326'},
 {'theme': 'constraint',
  'subtheme': 'Wood production',
  'name': 'Accessibility to major cities',
  'weight': 0,
  'layer': 'Oxford/MAP/accessibility_to_cities_2015_v1_0'},
 {'theme': 'benefits',
  'subtheme': 'Wood production',
  'name': 'Forest employment per ha of forest',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/emp_ha'},
 {'theme': 'benefits',
  'subtheme': 'Non-timber tree benefits',
  'name': 'Aboveground carbon accumulation from natural regeneration ',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/young_forest_sequestration_rate_Griscom_extent'},
 {'theme': 'benefits',
  'subtheme': 'Non-timber tree benefits',
  'name': '100 - Biodiversity Intactness Index (BII)',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/ibii-4326'},
 {'theme': 'benefits',
  'subtheme': 'Non-timber tree benefits',
  'name': 'Endangered and critically endangered species',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/terra-bio-div-image'},
 {'theme': 'benefits',
  'subtheme': 'Local livelihoods',
  'name': 'Improved access to fuelwood for consumption by farmers - charcoal consumption for fuel and energy',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/Woodfuel_gadm36_1_edited_image'},
 {'theme': 'benefits',
  'subtheme': 'Local livelihoods',
  'name': 'erosion prevention on steep slopes',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'benefits',
  'subtheme': 'Water quality',
  'name': 'targeted on degraded water towers which are sources of water for communities, livestock and wildlife (tourism backbone) downstream.',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'constraint',
  'subtheme': 'biophysical ',
  'name': 'restoration potential in LMICs (lack trees and are not urban == “restorable land”)',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'constraint',
  'subtheme': 'biophysical ',
  'name': 'terrestrial ecoregions',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/gez_2010_wgs84_split'},
 {'theme': 'constraint',
  'subtheme': 'land cover & management',
  'name': 'Current land cover',
  'weight': 0,
  'layer': 'COPERNICUS/Landcover/100m/Proba-V-C3/Global/2019'},
 {'theme': 'constraint',
  'subtheme': 'land cover & management',
  'name': 'Protected areas',
  'weight': 0,
  'layer': 'WCMC/WDPA/current/polygons'},
 {'theme': 'constraint',
  'subtheme': 'biophysical ',
  'name': 'Slope',
  'weight': 0,
  'layer': 'CGIAR/SRTM90_V4'},
 {'theme': 'constraint',
  'subtheme': 'biophysical ',
  'name': 'Elevation',
  'weight': 0,
  'layer': 'CGIAR/SRTM90_V4'},
 {'theme': 'constraint',
  'subtheme': '',
  'name': 'water stress',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'costs',
  'subtheme': 'monetary',
  'name': 'opportunity cost,cropland value',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/crop_va'},
 {'theme': 'costs',
  'subtheme': 'monetary',
  'name': 'opportunity cost,pastureland value',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/pasture_va'},
 {'theme': 'costs',
  'subtheme': 'monetary',
  'name': 'establishment cost afforestation',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/AfCost_ha'},
 {'theme': 'constraint',
  'subtheme': 'non-monetary',
  'name': 'Landscape variation in natural regeneration success',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/Regeneration '},
 {'theme': 'constraint',
  'subtheme': 'non-monetary',
  'name': 'Locations with declining population',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/population_decline_masked'},
 {'theme': 'costs',
  'subtheme': '',
  'name': 'mortality/success rate of seedlings',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'costs',
  'subtheme': '',
  'name': 'cost of planting',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'risks',
  'subtheme': 'Economic indicators',
  'name': 'Real interest rate',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/national_RealInterestRate'},
 {'theme': 'risks',
  'subtheme': 'Economic indicators',
  'name': 'Country risk premium',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/national_RiskPremium'},
 {'theme': 'risks',
  'subtheme': 'Institutional indicators',
  'name': 'Governance index',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/national_Governance_PC1'},
 {'theme': 'risks',
  'subtheme': 'Institutional indicators',
  'name': 'Rule of Law (downscaled to 1st level subnational administrative unit)',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/RL_gadm36_1_edited_image'},
 {'theme': 'risks',
  'subtheme': 'Institutional indicators',
  'name': 'Perceived property security',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/national_OtherPropertySecure'},
 {'theme': 'risks',
  'subtheme': 'Institutional indicators',
  'name': 'Land designated for or owned by IP and LC',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/national_IP_LC'},
 {'theme': 'constraint',
  'subtheme': 'Environmental indicators',
  'name': 'Forest cover change in 5 km buffer',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/DeforestRate'},
 {'theme': 'constraint',
  'subtheme': 'Environmental indicators',
  'name': 'Climate risk',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/future_risk'},
 {'theme': 'risks',
  'subtheme': 'biophysical ',
  'name': 'fires',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'risks',
  'subtheme': 'land cover & management',
  'name': 'grazing',
  'weight': 0,
  'layer': 'users/bornToBeAlive/random300'},
 {'theme': 'costs',
  'subtheme': 'monetary',
  'name': 'establishment cost reforestation',
  'weight': 0,
  'layer': 'projects/john-ee-282116/assets/fao-restoration/features/ReCost_ha'},
 {'theme': 'constraint',
  'subtheme': '',
  'name': 'Population',
  'weight': 0,
  'layer': 'CIESIN/GPWv411/GPW_Population_Count/gpw_v4_population_count_rev11_2020_30_sec'}]

# %%
rp_layers.table.items = a
