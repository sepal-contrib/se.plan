# %%
from scripts.tile import *
import ipyvuetify as v 
import traitlets
# Out:
# HTML(value='\n<style>\n.leaflet-pane {\n    z-index : 2 !important;\n}\n.leaflet-top, .leaflet-bottom {\n    z…
# ResizeTrigger()

# %%
io = customize_layer_io()

# %%
clt = CustomizeLayerTile(io)

# %%
lt = LayerTable()
lt
# Out:
# LayerTable(headers=[{'text': 'Theme', 'value': 'theme'}, {'text': 'Sub theme', 'value': 'subtheme'}, {'text': …

# %%
ed = EditDialog()
ed.value = True
ed
# Out:
# EditDialog(children=[Card(children=[CardTitle(children=['Layer name']), CardText(children=['Particular wonder …

# %%
lt.v_model
# Out:
# []

# %%
from faker import Faker
fake = Faker()

import pandas as pd

# %%
file = 'data/layer_list.csv'
df = pd.read_csv(file)
df
# Out:
#          theme                                           subtheme  \
# 0     benefits                                    wood production
# 1     benefits                                    wood production
# 2     benefits                                    wood production
# 3     benefits                                    wood production
# 4     benefits                                    wood production
# 5     benefits                                         non-timber
# 6     benefits                                         non-timber
# 7     benefits                                         non-timber
# 8     benefits             Supporting livelihoods of local people
# 9     benefits  Supporting livelihoods of local people (lowlan...
# 10    benefits                                      water quality
# 11  constraint                                       biophysical
# 12  constraint                                       biophysical
# ...

# %%
df['layer_info'] = Fake()
