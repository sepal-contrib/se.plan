# %%
import pygaul
import ee
import geopandas as gpd
ee.Initialize()

# %%
admin = "Risaralda"

# %%
feature_collection = pygaul.AdmItems(name=admin)

# %%
features = feature_collection.getInfo()["features"]

# %%
features
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-75.88099525703937, 5.134400708103579],
#      [-75.88159726811026, 5.125799057850983],
#      [-75.8839026489505, 5.115997980571393],
#      [-75.88559704883002, 5.112502061400686],
#      [-75.88970395852098, 5.109099784728734],
#      [-75.89309729578495, 5.080200340482164],
#      [-75.88439757854975, 5.068602195581956],
#      [-75.88439757854975, 5.061699526175685],
#      [-75.8861990402676, 5.058199093160781],
#      [-75.88899934799036, 5.051300870570475],
#      [-75.89019886776181, 5.037999383344504],
#      [-75.89479619376023, 5.022998965104989],
#      [-75.89479619376023, 5.017202146190034],
#      [-75.89820296796162, 5.00169785746435],
#      [-75.89249976521538, 5.004498198288605],
#      [-75.88500400675542, 5.010299442667004],
#      [-75.8769018327732, 5.014299244244211],
#      [-75.86599937212135, 5.022900911494279],
#      [-75.85209588716742, 5.038400692174407],
# ...
