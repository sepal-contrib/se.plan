# %%
#add tiles 
# %run 'aoi_ui.ipynb'
# %run 'questionnaire_ui.ipynb'
# %run 'customize_layer_ui.ipynb'
# %run 'compute_ui.ipynb'

# %%
rp_aoi

# %%
rp_questionnaire

# %%
rp_layers

# %%
rp_validation

# %%
rp_map_tile

# %%
rp_regions

# %%
rp_theme

# %%
#import geemap 

#geemap.geojson_to_ee(rp_map_tile.draw_features['features'][0])
