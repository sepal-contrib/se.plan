# %%
#add tiles 
# %run 'aoi_ui.ipynb'
# %run 'questionnaire_ui.ipynb'
# %run 'customize_layer_ui.ipynb'
# %run 'compute_ui.ipynb'

# %%
rp_aoi

# %%
rp_questionnaire

# %%
rp_layers

# %%
rp_validation

# %%
rp_compute

# %%
rp_dashboard

# %%
rp_map_tile
